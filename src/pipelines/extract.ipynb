# %%
import pandas as pd
import yfinance as yf

tickers = ['AAPL', 'MSFT']
historical_data = []
year = 2023
for ticker in tickers:
    stock = yf.Ticker(ticker)
    info = stock.info
    start_date = f"{year}-11-30"
    end_date = f"{year}-12-31"
    try:
        hist = stock.history(start=start_date, end=end_date)
        for index, row in hist.iterrows():
            data = {
                "company_id": info.get("uuid", ""),
                "date": index.date(),
                "ticker": ticker,
                "price": row['Close'],
                "industry": info.get("industry", "")
            }
            historical_data.append(data)
    except Exception as e:
        print(f"Error extracting data for {ticker}: {e}")
        continue

df = pd.DataFrame(historical_data)
df.head(5)
# Out:
#                              company_id        date ticker       price  \
# 0  8b10e4ae-9eeb-3684-921a-9ab27e4d87aa  2023-11-30   AAPL  189.450958
# 1  8b10e4ae-9eeb-3684-921a-9ab27e4d87aa  2023-12-01   AAPL  190.737579
# 2  8b10e4ae-9eeb-3684-921a-9ab27e4d87aa  2023-12-04   AAPL  188.932327
# 3  8b10e4ae-9eeb-3684-921a-9ab27e4d87aa  2023-12-05   AAPL  192.911850
# 4  8b10e4ae-9eeb-3684-921a-9ab27e4d87aa  2023-12-06   AAPL  191.814758
#
#                industry
# 0  Consumer Electronics
# 1  Consumer Electronics
# 2  Consumer Electronics
# 3  Consumer Electronics
# 4  Consumer Electronics
